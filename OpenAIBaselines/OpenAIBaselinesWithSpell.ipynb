# %% [markdown]
# # Running OpenAI Baselines With Spell (Ex. Training PPO on OpenAI Gym)

# %%
import os
os.getcwd()
# Out:
# '/spell'

# %%
import sys
import multiprocessing
import os.path as osp
import gym
from collections import defaultdict
import tensorflow as tf
import numpy as np
import os
import time
import spell.metrics as metrics

from baselines.common.vec_env.vec_video_recorder import VecVideoRecorder
from baselines.common.vec_env.vec_frame_stack import VecFrameStack
from baselines.common.cmd_util import common_arg_parser, parse_unknown_args, make_vec_env, make_env
from baselines.common.tf_util import get_session
from importlib import import_module
from baselines.logger import KVWriter, HumanOutputFormat, CSVOutputFormat, JSONOutputFormat, TensorBoardOutputFormat
from baselines.ppo2.runner import Runner
from baselines.common import explained_variance, set_global_seeds
from baselines.common.policies import build_policy
from baselines.common.vec_env.vec_normalize import VecNormalize
from collections import deque

try:
    from mpi4py import MPI
except ImportError:
    MPI = None
    
try:
    import pybullet_envs
except ImportError:
    pybullet_envs = None

try:
    import roboschool
except ImportError:
    roboschool = None
    
# Load all OpenAI gym environments to dictionary, including Classic Control, Mujoco, Atari, etc.
# ----------------------------------------
_game_envs = defaultdict(set)
for env in gym.envs.registry.all():
    env_type = env._entry_point.split(':')[0].split('.')[-1]
    _game_envs[env_type].add(env.id)

_game_envs['retro'] = {
    'BubbleBobble-Nes',
    'SuperMarioBros-Nes',
    'TwinBee3PokoPokoDaimaou-Nes',
    'SpaceHarrier-Nes',
    'SonicTheHedgehog-Genesis',
    'Vectorman-Genesis',
    'FinalFight-Snes',
    'SpaceInvaders-Snes',
}

# %% [markdown]
# ### Load OpenAI Baselines Logger Class (modified to send metrics live to Spell)

# %%
DEBUG = 10
INFO = 20
WARN = 30
ERROR = 40

DISABLED = 50

class Logger(object):
    DEFAULT = None  # A logger with no output files.
    CURRENT = None  # Current logger being used

    def __init__(self, dir, output_formats):
        self.name2val = defaultdict(float)  # values this iteration
        self.name2cnt = defaultdict(int)
        self.level = INFO
        self.dir = dir
        self.output_formats = output_formats

    # Logging API,
    def logkv(self, key, val):
        self.name2val[key] = val
        if isinstance(val, np.float32): val = val.item()
        print(key, val)
        metrics.send_metric(key, val) # Send (key, val) to Spell as metric

    def logkv_mean(self, key, val):
        if val is None:
            self.name2val[key] = None
            return
        oldval, cnt = self.name2val[key], self.name2cnt[key]
        newval = oldval*cnt/(cnt+1) + val/(cnt+1)
        self.name2val[key] = newval
        if isinstance(newval, np.float32): newval = newval.item()
        metrics.send_metric(key, newval) # Send mean (key, val) to Spell as metric
        self.name2cnt[key] = cnt + 1

    def dumpkvs(self):
        if self.level == DISABLED: return
        for fmt in self.output_formats:
            if isinstance(fmt, KVWriter):
                fmt.writekvs(self.name2val)
        self.name2val.clear()
        self.name2cnt.clear()

    def log(self, *args, level=INFO):
        if self.level <= level:
            self._do_log(args)

    # Configuration
    # ----------------------------------------
    def set_level(self, level):
        self.level = level

    def get_dir(self):
        return self.dir

    def close(self):
        for fmt in self.output_formats:
            fmt.close()

    # Misc
    # ----------------------------------------
    def _do_log(self, args):
        for fmt in self.output_formats:
            if isinstance(fmt, SeqWriter):
                fmt.writeseq(map(str, args))

# %%
# Configure output log generator with specified format
# ----------------------------------------
def make_output_format(format, ev_dir, log_suffix=''):
    os.makedirs(ev_dir, exist_ok=True)
    if format == 'stdout':
        return HumanOutputFormat(sys.stdout)
    elif format == 'log':
        return HumanOutputFormat(osp.join(ev_dir, 'log%s.txt' % log_suffix))
    elif format == 'json':
        return JSONOutputFormat(osp.join(ev_dir, 'progress%s.json' % log_suffix))
    elif format == 'csv':
        return CSVOutputFormat(osp.join(ev_dir, 'progress%s.csv' % log_suffix))
    elif format == 'tensorboard':
        return TensorBoardOutputFormat(osp.join(ev_dir, 'tb%s' % log_suffix))
    else:
        raise ValueError('Unknown format specified: %s' % (format,))

# %% [markdown]
# ### Load OpenAI PPO2.py

# %%
import spell

def constfn(val):
    def f(_):
        return val
    return f

def learn(*, network, env, total_timesteps, eval_env = None, seed=None, nsteps=2048, ent_coef=0.0, lr=3e-4,
            vf_coef=0.5,  max_grad_norm=0.5, gamma=0.99, lam=0.95,
            log_interval=10, nminibatches=4, noptepochs=4, cliprange=0.2,
            save_interval=0, load_path=None, model_fn=None, **network_kwargs):
    '''
    Learn policy using PPO algorithm (https://arxiv.org/abs/1707.06347)

    Parameters:
    ----------

    network:                          policy network architecture. Either string (mlp, lstm, lnlstm, cnn_lstm, cnn, cnn_small, conv_only - see baselines.common/models.py for full list)
                                      specifying the standard network architecture, or a function that takes tensorflow tensor as input and returns
                                      tuple (output_tensor, extra_feed) where output tensor is the last network layer output, extra_feed is None for feed-forward
                                      neural nets, and extra_feed is a dictionary describing how to feed state into the network for recurrent neural nets.
                                      See common/models.py/lstm for more details on using recurrent nets in policies

    env: baselines.common.vec_env.VecEnv     environment. Needs to be vectorized for parallel environment simulation.
                                      The environments produced by gym.make can be wrapped using baselines.common.vec_env.DummyVecEnv class.


    nsteps: int                       number of steps of the vectorized environment per update (i.e. batch size is nsteps * nenv where
                                      nenv is number of environment copies simulated in parallel)

    total_timesteps: int              number of timesteps (i.e. number of actions taken in the environment)

    ent_coef: float                   policy entropy coefficient in the optimization objective

    lr: float or function             learning rate, constant or a schedule function [0,1] -> R+ where 1 is beginning of the
                                      training and 0 is the end of the training.

    vf_coef: float                    value function loss coefficient in the optimization objective

    max_grad_norm: float or None      gradient norm clipping coefficient

    gamma: float                      discounting factor

    lam: float                        advantage estimation discounting factor (lambda in the paper)

    log_interval: int                 number of timesteps between logging events

    nminibatches: int                 number of training minibatches per update. For recurrent policies,
                                      should be smaller or equal than number of environments run in parallel.

    noptepochs: int                   number of training epochs per update

    cliprange: float or function      clipping range, constant or schedule function [0,1] -> R+ where 1 is beginning of the training
                                      and 0 is the end of the training

    save_interval: int                number of timesteps between saving events

    load_path: str                    path to load the model from

    **network_kwargs:                 keyword arguments to the policy / network builder. See baselines.common/policies.py/build_policy and arguments to a particular type of network
                                      For instance, 'mlp' network architecture has arguments num_hidden and num_layers.



    '''

    set_global_seeds(seed)
    type(env)
    if isinstance(lr, float): lr = constfn(lr)
    else: assert callable(lr)
    if isinstance(cliprange, float): cliprange = constfn(cliprange)
    else: assert callable(cliprange)
    total_timesteps = int(total_timesteps)

    policy = build_policy(env, network, **network_kwargs)
    # Get the nb of env
    nenvs = env.num_envs
    # Get state_space and action_space
    ob_space = env.observation_space
    ac_space = env.action_space
    # Calculate the batch_size
    nbatch = nenvs * nsteps
    nbatch_train = nbatch // nminibatches
    
    # Instantiate the model object (that creates act_model and train_model)
    if model_fn is None:
        from baselines.ppo2.model import Model
        model_fn = Model
    model = model_fn(policy=policy, ob_space=ob_space, ac_space=ac_space, nbatch_act=nenvs, nbatch_train=nbatch_train,
                    nsteps=nsteps, ent_coef=ent_coef, vf_coef=vf_coef,
                    max_grad_norm=max_grad_norm)
    if load_path is not None:
        model.load(load_path)
        
    # Instantiate the runner object
    runner = Runner(env=env, model=model, nsteps=nsteps, gamma=gamma, lam=lam)
    if eval_env is not None:
        eval_runner = Runner(env = eval_env, model = model, nsteps = nsteps, gamma = gamma, lam= lam)
    epinfobuf = deque(maxlen=100)
    if eval_env is not None:
        eval_epinfobuf = deque(maxlen=100)
        
    # Start total timer
    tfirststart = time.time()
    nupdates = total_timesteps//nbatch
    
    for update in range(1, nupdates+1):
        assert nbatch % nminibatches == 0      
        # Start timer
        tstart = time.time()
        frac = 1.0 - (update - 1.0) / nupdates      
        # Calculate the learning rate
        lrnow = lr(frac)     
        # Calculate the cliprange
        cliprangenow = cliprange(frac)    
        # Get minibatch
        obs, returns, masks, actions, values, neglogpacs, states, epinfos = runner.run()
        if eval_env is not None:
            eval_obs, eval_returns, eval_masks, eval_actions, eval_values, eval_neglogpacs, eval_states, eval_epinfos = eval_runner.run() #pylint: disable=E0632
        epinfobuf.extend(epinfos)
        if eval_env is not None:
            eval_epinfobuf.extend(eval_epinfos)
            
        # Here what we're going to do is for each minibatch calculate the loss and append it.
        mblossvals = []
        if states is None: # nonrecurrent version
            # Index of each element of batch_size
            # Create the indices array
            inds = np.arange(nbatch)
            for _ in range(noptepochs):
                # Randomize the indices
                np.random.shuffle(inds)
                # 0 to batch_size with batch_train_size step
                for start in range(0, nbatch, nbatch_train):
                    end = start + nbatch_train
                    mbinds = inds[start:end]
                    slices = (arr[mbinds] for arr in (obs, returns, masks, actions, values, neglogpacs))
                    mblossvals.append(model.train(lrnow, cliprangenow, *slices))
        else: # recurrent version
            assert nenvs % nminibatches == 0
            envsperbatch = nenvs // nminibatches
            envinds = np.arange(nenvs)
            flatinds = np.arange(nenvs * nsteps).reshape(nenvs, nsteps)
            envsperbatch = nbatch_train // nsteps
            for _ in range(noptepochs):
                np.random.shuffle(envinds)
                for start in range(0, nenvs, envsperbatch):
                    end = start + envsperbatch
                    mbenvinds = envinds[start:end]
                    mbflatinds = flatinds[mbenvinds].ravel()
                    slices = (arr[mbflatinds] for arr in (obs, returns, masks, actions, values, neglogpacs))
                    mbstates = states[mbenvinds]
                    mblossvals.append(model.train(lrnow, cliprangenow, *slices, mbstates))
                    
        # Feedforward --> get losses --> update
        lossvals = np.mean(mblossvals, axis=0)
        # End timer
        tnow = time.time()
        # Calculate the fps (frame per second)
        fps = int(nbatch / (tnow - tstart))
        if update % log_interval == 0 or update == 1:
            # Calculates if value function is a good predicator of the returns (ev > 1)
            # or if it's just worse than predicting nothing (ev =< 0)
            ev = explained_variance(values, returns)
            # Log (key, value) tuples
            Logger.CURRENT.logkv("serial_timesteps", update*nsteps)
            Logger.CURRENT.logkv("nupdates", update)
            Logger.CURRENT.logkv("total_timesteps", update*nbatch)
            Logger.CURRENT.logkv("fps", fps)
            Logger.CURRENT.logkv("explained_variance", float(ev))
            Logger.CURRENT.logkv('eprewmean', safemean([epinfo['r'] for epinfo in epinfobuf]))
            Logger.CURRENT.logkv('eplenmean', safemean([epinfo['l'] for epinfo in epinfobuf]))
            if eval_env is not None:
                Logger.CURRENT.logger.logkv('eval_eprewmean', safemean([epinfo['r'] for epinfo in eval_epinfobuf]) )
                Logger.CURRENT.logger.logkv('eval_eplenmean', safemean([epinfo['l'] for epinfo in eval_epinfobuf]) )
            Logger.CURRENT.logkv('time_elapsed', tnow - tfirststart)
            for (lossval, lossname) in zip(lossvals, model.loss_names):
                Logger.CURRENT.logkv(lossname, lossval)
            if MPI is None or MPI.COMM_WORLD.Get_rank() == 0:
                Logger.CURRENT.dumpkvs()
        if save_interval and (update % save_interval == 0 or update == 1) and Logger.CURRENT.get_dir() and (MPI is None or MPI.COMM_WORLD.Get_rank() == 0):
            checkdir = osp.join(Logger.CURRENT.get_dir(), 'checkpoints')
            os.makedirs(checkdir, exist_ok=True)
            savepath = osp.join(checkdir, '%.5i'%update)
            print('Saving to', savepath)
            model.save(savepath)
    return model

# Avoid division error when calculating the mean (in our case if epinfo is empty returns np.nan, not return an error)
def safemean(xs):
    return np.nan if len(xs) == 0 else np.mean(xs)

# %% [markdown]
# ## Set Arguments and Hyperparameters

# %%
# Total number of training timesteps
total_timesteps = 2e7

# OpenAI Gym training environment ID (navigate to https://gym.openai.com/envs/ to see the full list of environments)
env_id = 'PongNoFrameskip-v4'

# Any of {'csv', 'json', 'stdout','tensorboard'}
log_formats = ['csv']

# Name of folder to which run logs and the trained model will be saved, 
# accessible via run 'outputs' through the Spell web console
save_path = 'pong-ppo' 

# Dictionary with values of training hyperparameters (see 'learn' fn above for more details)
alg_kwargs = {'nsteps': 128} 

# Policy Network Architecture (for more details, see baselines.common/models.py)
network = 'mlp'

# %% [markdown]
# ## Initialize the Training Environment

# %%
# Retrieve env_type, env_id
for env in gym.envs.registry.all():
    env_type = env._entry_point.split(':')[0].split('.')[-1]
    _game_envs[env_type].add(env.id)  # This is a set so add is idempotent

if env_id in _game_envs.keys():
    env_type = env_id
    env_id = [g for g in _game_envs[env_type]][0]
else:
    env_type = None
    for g, e in _game_envs.items():
        if env_id in e:
            env_type = g
            break
            
# Build environment
ncpu = multiprocessing.cpu_count()
if sys.platform == 'darwin': ncpu //= 2
nenv = ncpu

frame_stack_size = 4
env = make_vec_env(env_id, env_type, nenv, None, gamestate=None, reward_scale=1.0)
env = VecFrameStack(env, frame_stack_size)
# Out:
# Logging to /tmp/openai-2019-05-01-13-57-55-069281

# %% [markdown]
# ## Configure Logger

# %%
# Create folder where logs and trained model will be saved
os.makedirs(save_path, exist_ok=True)

# Initialize output formatter
output_formats = [make_output_format(f, save_path, '') for f in log_formats]

# Create instance of Logger, with appropriate path and output formatter
Logger.CURRENT = Logger(dir=save_path, output_formats=output_formats)

# %% [markdown]
# ## Train the Agent

# %%
# Run PPO learning function, with parameters set above
model = learn(network=network, env=env, seed=None, total_timesteps=total_timesteps, **alg_kwargs)
# Out:
# WARNING:tensorflow:From /spell/baselines/common/input.py:57: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /spell/baselines/common/models.py:50: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# serial_timesteps 128
# nupdates 1
# total_timesteps 1024
# fps 630
# explained_variance -0.3197333812713623
# eprewmean nan
# eplenmean nan
# time_elapsed 1.6245479583740234
# policy_loss -0.003534963820129633
# value_loss 0.15454864501953125
# policy_entropy 1.7900211811065674
# approxkl 0.0012844200246036053
# clipfrac 0.0
# /usr/local/lib/python3.6/dist-packages/spell/metrics.py:66: SpellMetricWarning: metric discarded: invalid 'float': 'nan' not supported
#   warnings.warn("metric discarded: {}".format(r.text), SpellMetricWarning)
# serial_timesteps 1280
# nupdates 10
# total_timesteps 10240
# fps 1205
# explained_variance -1.1920928955078125e-07
# eprewmean -20.625
# eplenmean 856.0
# time_elapsed 9.28946566581726
# policy_loss -0.0007985357078723609
# value_loss 0.06704077869653702
# policy_entropy 1.7596828937530518
# approxkl 0.0007249721675179899
# clipfrac 0.0
# serial_timesteps 2560
# nupdates 20
# total_timesteps 20480
# fps 1177
# explained_variance -0.01451730728149414
# eprewmean -20.63157894736842
# eplenmean 851.4736842105264
# time_elapsed 17.97952389717102
# policy_loss -0.0018938612192869186
# value_loss 0.06470620632171631
# policy_entropy 1.6955180168151855
# approxkl 0.0018485903274267912
# clipfrac 0.0
# serial_timesteps 3840
# nupdates 30
# total_timesteps 30720
# fps 1293
# explained_variance 0.0
# eprewmean -20.59375
# eplenmean 848.375
# time_elapsed 26.498246908187866
# policy_loss -0.007045030128210783
# value_loss 0.04981540888547897
# policy_entropy 1.7400890588760376
# approxkl 0.003627749625593424
# clipfrac 0.02783203125
# serial_timesteps 5120
# nupdates 40
# total_timesteps 40960
# fps 1031
# explained_variance -0.011771559715270996
# eprewmean -20.608695652173914
# eplenmean 843.6739130434783
# time_elapsed 35.511303424835205
# policy_loss -0.001086787786334753
# value_loss 0.08223632723093033
# policy_entropy 1.75406014919281
# approxkl 0.0002535241947043687
# clipfrac 0.0
# serial_timesteps 6400
# nupdates 50
# total_timesteps 51200
# fps 1184
# explained_variance -1.1920928955078125e-07
# eprewmean -20.660714285714285
# eplenmean 836.0892857142857
# time_elapsed 44.27232122421265
# policy_loss -0.00032917349017225206
# value_loss 0.04635677859187126
# policy_entropy 1.702144980430603
# approxkl 0.001064061769284308
# clipfrac 0.0
# serial_timesteps 7680
# explained_variance 0.0011729001998901367
# eprewmean -20.24
# eplenmean 880.69
# time_elapsed 373.04671120643616
# policy_loss -0.0038914813194423914
# value_loss 0.058848150074481964
# policy_entropy 1.3236438035964966
# approxkl 0.001391714671626687
# clipfrac 0.0
# serial_timesteps 55040
# nupdates 430
# total_timesteps 440320
# fps 1092
# explained_variance 0.0027396082878112793
# eprewmean -20.18
# eplenmean 891.16
# time_elapsed 382.00063920021057
# policy_loss -0.0016766887856647372
# value_loss 0.0701051577925682
# policy_entropy 1.1949799060821533
# approxkl 0.002404292579740286
# clipfrac 0.0
# serial_timesteps 56320
# nupdates 440
# total_timesteps 450560
# fps 1088
# explained_variance 0.0
# eprewmean -20.16
# eplenmean 895.2
# time_elapsed 390.62682914733887
# policy_loss 7.83443683758378e-05
# value_loss 0.04782789573073387
# policy_entropy 1.2382330894470215
# approxkl 0.00014581906725652516
# clipfrac 0.0
# serial_timesteps 57600
# nupdates 450
# total_timesteps 460800
# fps 1039
# explained_variance 0.0019336938858032227
# eprewmean -20.21
# eplenmean 891.27
# time_elapsed 400.3446002006531
# policy_loss -0.002512793056666851
# value_loss 0.07446520030498505
# policy_entropy 1.3081613779067993
# approxkl 0.003605406964197755
# clipfrac 0.037353515625
# serial_timesteps 58880
# nupdates 460
# total_timesteps 471040
# fps 1181
# explained_variance 0.00233381986618042
# eprewmean -20.17
# eplenmean 897.57
# time_elapsed 409.2891056537628
# policy_loss -0.0016947038238868117
# value_loss 0.0618002824485302
# policy_entropy 1.1605957746505737
# approxkl 0.0010166409192606807
# clipfrac 0.0
# serial_timesteps 60160
# nupdates 470
# total_timesteps 481280
# fps 1186
# explained_variance 0.002408444881439209
# eprewmean -20.15
# eplenmean 901.92
# time_elapsed 417.75609278678894
# policy_loss 0.0001052030420396477
# value_loss 0.054542601108551025
# policy_entropy 1.2219308614730835
# approxkl 4.145153798162937e-05
# clipfrac 0.0
# serial_timesteps 61440
# nupdates 480
# total_timesteps 491520
# fps 1152
# explained_variance 0.004948675632476807
# eprewmean -20.18
# eplenmean 901.37
# time_elapsed 426.60041403770447
# policy_loss -0.0008532165084034204
# value_loss 0.05385265499353409
# policy_entropy 1.2658348083496094
# approxkl 0.0008269623504020274
# clipfrac 0.0009765625
# serial_timesteps 62720
# nupdates 490
# total_timesteps 501760
# fps 1219
# explained_variance 0.0
# eprewmean -20.17
# eplenmean 905.07
# time_elapsed 435.29818654060364
# policy_loss -0.003048898885026574
# value_loss 0.05864300951361656
# policy_entropy 1.222095012664795
# approxkl 0.0020390814170241356
# clipfrac 0.0
# serial_timesteps 64000
# nupdates 500
# total_timesteps 512000
# fps 1132
# explained_variance 0.0037076473236083984
# eprewmean -20.24
# eplenmean 899.64
# time_elapsed 444.2496123313904
# policy_loss -0.000802484224550426
# value_loss 0.06487640738487244
# policy_entropy 1.342068076133728
# approxkl 0.0015508728101849556
# clipfrac 0.0
# serial_timesteps 65280
# nupdates 510
# total_timesteps 522240
# fps 1174
# explained_variance 0.0031173229217529297
# eprewmean -20.3
# eplenmean 892.72
# time_elapsed 452.94080233573914
# policy_loss -0.000499771093018353
# value_loss 0.05970185995101929
# policy_entropy 1.2825064659118652
# approxkl 0.000183666474185884
# clipfrac 0.0
# serial_timesteps 66560
# nupdates 520
# total_timesteps 532480
# fps 1295
# explained_variance 0.004415333271026611
# eprewmean -20.26
# eplenmean 889.04
# time_elapsed 461.8071086406708
# policy_loss -0.001054689520969987
# value_loss 0.0499313548207283
# policy_entropy 1.4170669317245483
# approxkl 0.0007315800176002085
# clipfrac 0.001220703125
# serial_timesteps 67840
# nupdates 530
# total_timesteps 542720
# fps 1181
# explained_variance -1.1920928955078125e-07
# eprewmean -20.3
# eplenmean 886.82
# time_elapsed 470.75102066993713
# policy_loss -0.0005954786320216954
# value_loss 0.054583508521318436
# policy_entropy 1.1590794324874878
# approxkl 0.0008193369139917195
# clipfrac 0.0
# serial_timesteps 69120
# nupdates 540
# total_timesteps 552960
# fps 1186
# explained_variance 0.005883693695068359
# eprewmean -20.3
# eplenmean 875.72
# time_elapsed 479.41200971603394
# policy_loss -0.0001848911924753338
# value_loss 0.061115190386772156
# policy_entropy 1.1475765705108643
# approxkl 0.0007315388065762818
# clipfrac 0.0
# serial_timesteps 70400
# nupdates 550
# total_timesteps 563200
# fps 1113
# explained_variance 0.0032552480697631836
# eprewmean -20.34
# eplenmean 864.76
# time_elapsed 488.17826557159424
# policy_loss -0.0003715409548021853
# value_loss 0.05959676206111908
# policy_entropy 1.1256747245788574
# approxkl 0.0006303564878180623
# clipfrac 0.0
# serial_timesteps 71680
# nupdates 560
# total_timesteps 573440
# fps 1165
# explained_variance 0.0029001235961914062
# eprewmean -20.31
# eplenmean 866.52
# time_elapsed 496.9408423900604
# policy_loss -0.002888896968215704
# value_loss 0.05601191520690918
# policy_entropy 1.223427653312683
# approxkl 0.0017893421463668346
# clipfrac 0.0166015625
# serial_timesteps 72960
# nupdates 570
# total_timesteps 583680
# fps 1227
# explained_variance 0.0008805990219116211
# eprewmean -20.4
# eplenmean 853.58
# time_elapsed 505.91349697113037
# policy_loss 9.191765275318176e-05
# value_loss 0.05510304495692253
# policy_entropy 1.134380578994751
# approxkl 0.00015743941185064614
# clipfrac 0.0
# serial_timesteps 74240
# nupdates 580
# total_timesteps 593920
# fps 1205
# explained_variance 0.0028908848762512207
# eprewmean -20.4
# eplenmean 851.0
# time_elapsed 514.763699054718
# policy_loss 0.00035774201387539506
# value_loss 0.05096600204706192
# policy_entropy 1.266047477722168
# approxkl 0.0006049826624803245
# clipfrac 0.0
# serial_timesteps 75520
# nupdates 590
# total_timesteps 604160
# fps 1131
# explained_variance 0.0017572641372680664
# eprewmean -20.38
# eplenmean 855.81
# time_elapsed 523.7220876216888
# policy_loss -0.002703008009120822
# value_loss 0.06613332778215408
# policy_entropy 1.346318244934082
# approxkl 0.001612028107047081
# clipfrac 0.005615234375
# serial_timesteps 76800
# nupdates 600
# total_timesteps 614400
# fps 1161
# explained_variance 0.0036520957946777344
# eprewmean -20.44
# eplenmean 854.74
# time_elapsed 532.6099157333374
# policy_loss -1.4618388377130032e-05
# value_loss 0.05168689414858818
# policy_entropy 1.3720494508743286
# approxkl 0.0002730681444518268
# clipfrac 0.000732421875
# serial_timesteps 78080
# nupdates 610
# total_timesteps 624640
# fps 1131
# explained_variance 0.0025045275688171387
# eprewmean -20.38
# eplenmean 861.47
# time_elapsed 541.6867175102234
# policy_loss -0.0004306550254113972
# value_loss 0.06428452581167221
# policy_entropy 1.2552889585494995
# approxkl 0.0006036910926923156
# clipfrac 0.0
# serial_timesteps 79360
# nupdates 620
# total_timesteps 634880
# fps 1146
# explained_variance 0.003320455551147461
# eprewmean -20.36
# eplenmean 867.62
# time_elapsed 550.7482643127441
# policy_loss -0.001134349498897791
# value_loss 0.05416909232735634
# policy_entropy 1.274311900138855
# approxkl 0.0012366364244371653
# clipfrac 0.00048828125
# serial_timesteps 80640
# nupdates 630
# total_timesteps 645120
# fps 1102
# explained_variance -2.384185791015625e-07
# eprewmean -20.27
# eplenmean 880.43
# time_elapsed 559.6202297210693
# policy_loss -0.0016220749821513891
# value_loss 0.0699719563126564
# policy_entropy 1.2514811754226685
# approxkl 0.001368121593259275
# clipfrac 0.0
# serial_timesteps 81920
# nupdates 640
# total_timesteps 655360
# fps 1179
# explained_variance 0.003343820571899414
# eprewmean -20.18
# eplenmean 892.58
# time_elapsed 568.6635501384735
# policy_loss -0.001006795559078455
# value_loss 0.05464908108115196
# policy_entropy 1.2605665922164917
# approxkl 0.0004973990144208074
# clipfrac 0.0
# serial_timesteps 83200
# nupdates 650
# total_timesteps 665600
# fps 1170
# explained_variance 0.0006123185157775879
# eprewmean -20.17
# eplenmean 893.8
# time_elapsed 577.606292963028
# policy_loss -5.3462485084310174e-05
# value_loss 0.06194880232214928
# policy_entropy 1.4479053020477295
# approxkl 0.0002839007356669754
# clipfrac 0.0
# serial_timesteps 84480
# nupdates 660
# total_timesteps 675840
# fps 1191
# explained_variance 0.0035192370414733887
# eprewmean -20.13
# eplenmean 903.33
# time_elapsed 586.2727510929108
# policy_loss -0.0005116084357723594
# value_loss 0.04981321841478348
# policy_entropy 1.2442622184753418
# approxkl 0.00041605252772569656
# clipfrac 0.0
# serial_timesteps 85760
# nupdates 670
# total_timesteps 686080
# fps 1149
# explained_variance 0.0
# eprewmean -20.12
# eplenmean 902.64
# time_elapsed 595.1314873695374
# policy_loss -0.00012849053018726408
# value_loss 0.04734671115875244
# policy_entropy 1.182091474533081
# approxkl 0.00011058835661970079
# clipfrac 0.0
# serial_timesteps 87040
# nupdates 680
# total_timesteps 696320
# fps 1180
# explained_variance 0.0
# eprewmean -20.16
# eplenmean 895.47
# time_elapsed 604.0039658546448
# policy_loss -4.172633634880185e-05
# value_loss 0.04737257957458496
# policy_entropy 1.1535224914550781
# approxkl 7.452596037182957e-05
# clipfrac 0.0
# serial_timesteps 88320
# nupdates 690
# total_timesteps 706560
# fps 1225
# explained_variance 0.0026463866233825684
# eprewmean -20.17
# eplenmean 890.25
# value_loss 0.06407759338617325
# policy_entropy 1.2299171686172485
# approxkl 8.076812810031697e-05
# clipfrac 0.0
# serial_timesteps 112640
# nupdates 880
# total_timesteps 901120
# fps 1222
# explained_variance 0.004352748394012451
# eprewmean -20.28
# eplenmean 863.86
# time_elapsed 782.0266540050507
# policy_loss -0.0005279278848320246
# value_loss 0.05064617842435837
# policy_entropy 1.2940620183944702
# approxkl 0.0007123915711417794
# clipfrac 0.0
# serial_timesteps 113920
# nupdates 890
# total_timesteps 911360
# fps 1176
# explained_variance 5.960464477539063e-08
# eprewmean -20.34
# eplenmean 857.37
# time_elapsed 791.0615487098694
# policy_loss -0.0031059591565281153
# value_loss 0.04673847556114197
# policy_entropy 1.2425264120101929
# approxkl 0.0018557345028966665
# clipfrac 0.011962890625
# serial_timesteps 115200
# nupdates 900
# total_timesteps 921600
# fps 1170
# explained_variance 5.960464477539063e-08
# eprewmean -20.38
# eplenmean 844.06
# time_elapsed 799.9541013240814
# policy_loss -0.0007938024937175214
# value_loss 0.0558701753616333
# policy_entropy 0.8816778659820557
# approxkl 0.00018012028886005282
# clipfrac 0.0
# serial_timesteps 116480
# nupdates 910
# total_timesteps 931840
# fps 1238
# explained_variance 0.0
# eprewmean -20.39
# eplenmean 838.51
# time_elapsed 808.5553228855133
# policy_loss -0.0011499441461637616
# value_loss 0.0459892675280571
# policy_entropy 1.078449010848999
# approxkl 0.0011423664400354028
# clipfrac 0.0
# serial_timesteps 117760
# nupdates 920
# total_timesteps 942080
# fps 1166
# explained_variance 0.0034359097480773926
# eprewmean -20.46
# eplenmean 825.18
# time_elapsed 817.1799745559692
# policy_loss -0.0041553303599357605
# value_loss 0.058685436844825745
# policy_entropy 0.998388409614563
# approxkl 0.0026938270311802626
# clipfrac 0.044189453125
# serial_timesteps 119040
# nupdates 930
# total_timesteps 952320
# fps 1179
# explained_variance 0.0
# eprewmean -20.44
# eplenmean 827.19
# time_elapsed 826.1551113128662
# policy_loss -0.0005288891843520105
# value_loss 0.045648276805877686
# policy_entropy 1.025193691253662
# approxkl 0.00020763897919096053
# clipfrac 0.0
# serial_timesteps 120320
# nupdates 940
# total_timesteps 962560
# fps 1227
# explained_variance 0.0
# eprewmean -20.49
# eplenmean 823.91
# time_elapsed 834.7567157745361
# policy_loss 0.00010159495286643505
# value_loss 0.04419022053480148
# policy_entropy 1.0784685611724854
# approxkl 0.00036314004682935774
# clipfrac 0.0
# serial_timesteps 121600
# nupdates 950
# total_timesteps 972800
# fps 1112
# explained_variance 0.002161085605621338
# eprewmean -20.5
# eplenmean 821.05
# time_elapsed 843.7177889347076
# policy_loss -0.0020373836159706116
# value_loss 0.0630733072757721
# policy_entropy 1.1528280973434448
# approxkl 0.0008801266667433083
# clipfrac 0.015625
# serial_timesteps 122880
# nupdates 960
# total_timesteps 983040
# fps 1137
# explained_variance -0.0007503032684326172
# eprewmean -20.44
# eplenmean 828.57
# time_elapsed 852.7514555454254
# policy_loss -0.0008353479206562042
# value_loss 0.05423133820295334
# policy_entropy 1.3188414573669434
# approxkl 0.0008470361353829503
# clipfrac 0.0
# serial_timesteps 124160
# nupdates 970
# total_timesteps 993280
# fps 1105
# explained_variance 0.0029775500297546387
# eprewmean -20.41
# eplenmean 830.92
# time_elapsed 861.6178107261658
# policy_loss -0.0013598958030343056
# value_loss 0.05704595148563385
# policy_entropy 1.2988312244415283
# approxkl 0.0006227137055248022
# clipfrac 0.001708984375
# serial_timesteps 125440
# nupdates 980
# total_timesteps 1003520
# fps 1363
# explained_variance 0.0
# eprewmean -20.42
# eplenmean 829.98
# time_elapsed 870.6143569946289
# policy_loss -0.0007645637961104512
# value_loss 0.06450964510440826
# policy_entropy 1.408947229385376
# approxkl 0.0006517560686916113
# clipfrac 0.0
# serial_timesteps 126720
# nupdates 990
# total_timesteps 1013760
# fps 1134
# explained_variance 0.0032919645309448242
# eprewmean -20.35
# eplenmean 839.89
# time_elapsed 879.0874130725861
# policy_loss -0.0012389128096401691
# value_loss 0.05005162954330444
# policy_entropy 1.326659083366394
# approxkl 0.0004549458681140095
# clipfrac 0.0
# serial_timesteps 128000
# nupdates 1000
# total_timesteps 1024000
# fps 1201
# explained_variance 0.0007314085960388184
# eprewmean -20.37
# eplenmean 846.18
# time_elapsed 888.1125917434692
# policy_loss -0.0021168235689401627
# value_loss 0.06511886417865753
# policy_entropy 1.4172446727752686
# approxkl 0.000971226196270436
# clipfrac 0.011962890625
# serial_timesteps 129280
# nupdates 1010
# total_timesteps 1034240
# fps 1155
# explained_variance 0.0020645856857299805
# eprewmean -20.37
# eplenmean 849.74
# time_elapsed 896.9406287670135
# policy_loss -0.0004727142513729632
# value_loss 0.06402097642421722
# policy_entropy 1.4740394353866577
# approxkl 0.0003454968973528594
# clipfrac 0.0
# serial_timesteps 130560
# nupdates 1020
# total_timesteps 1044480
# fps 1149
# explained_variance 0.0
# eprewmean -20.36
# eplenmean 857.44
# time_elapsed 905.9543850421906
# policy_loss -0.0005746671231463552
# value_loss 0.04428720474243164
# policy_entropy 1.1548806428909302
# approxkl 0.0005854574264958501
# clipfrac 0.0
# serial_timesteps 131840
# nupdates 1030
# total_timesteps 1054720
# fps 1326
# explained_variance 0.0
# eprewmean -20.44
# eplenmean 849.86
# time_elapsed 914.8320891857147
# policy_loss -5.051138577982783e-05
# value_loss 0.043857574462890625
# policy_entropy 1.0422240495681763
# approxkl 0.0001795981079339981
# clipfrac 0.0
# serial_timesteps 133120
# nupdates 1040
# total_timesteps 1064960
# fps 1139
# explained_variance 0.0030614137649536133
# eprewmean -20.53
# eplenmean 839.35
# time_elapsed 923.7745358943939
# policy_loss -0.0007619952084496617
# value_loss 0.054762400686740875
# policy_entropy 1.1368781328201294
# approxkl 0.00035366599331609905
# clipfrac 0.0
# serial_timesteps 134400
# nupdates 1050
# total_timesteps 1075200
# fps 1118
# explained_variance 0.004063248634338379
# eprewmean -20.59
# eplenmean 830.37
# time_elapsed 932.5505673885345
# policy_loss -0.0010824007913470268
# value_loss 0.05489366129040718
# value_loss 0.05190284922719002
# policy_entropy 1.4586713314056396
# approxkl 0.0014191876398399472
# clipfrac 0.0
# serial_timesteps 147200
# nupdates 1150
# total_timesteps 1177600
# fps 1047
# explained_variance 0.0
# eprewmean -20.65
# eplenmean 827.17
# time_elapsed 1020.4029424190521
# policy_loss -0.0007020185003057122
# value_loss 0.04675430431962013
# policy_entropy 1.5048422813415527
# approxkl 0.0005321897333487868
# clipfrac 0.0
# serial_timesteps 148480
# nupdates 1160
# total_timesteps 1187840
# fps 1102
# explained_variance 0.002858877182006836
# eprewmean -20.72
# eplenmean 825.13
# time_elapsed 1029.4924759864807
# policy_loss -0.003108738921582699
# value_loss 0.05632339045405388
# policy_entropy 1.497789740562439
# approxkl 0.001624269294552505
# clipfrac 0.0
# serial_timesteps 149760
# nupdates 1170
# total_timesteps 1198080
# fps 1223
# explained_variance 0.0
# eprewmean -20.73
# eplenmean 824.8
# time_elapsed 1038.5258011817932
# policy_loss -0.0025568846613168716
# value_loss 0.06491877138614655
# policy_entropy 1.390798807144165
# approxkl 0.002106688916683197
# clipfrac 0.0
# serial_timesteps 151040
# nupdates 1180
# total_timesteps 1208320
# fps 1151
# explained_variance 0.005097508430480957
# eprewmean -20.72
# eplenmean 821.25
# time_elapsed 1047.2141592502594
# policy_loss -0.0019145780242979527
# value_loss 0.06141927093267441
# policy_entropy 1.2754629850387573
# approxkl 0.0006867470219731331
# clipfrac 0.0078125
# serial_timesteps 152320
# nupdates 1190
# total_timesteps 1218560
# fps 1184
# explained_variance 5.960464477539063e-08
# eprewmean -20.71
# eplenmean 823.69
# time_elapsed 1056.116840839386
# policy_loss -0.0002330081770196557
# value_loss 0.05496622249484062
# policy_entropy 1.4462225437164307
# approxkl 0.0003111068799626082
# clipfrac 0.0
# serial_timesteps 153600
# nupdates 1200
# total_timesteps 1228800
# fps 1279
# explained_variance 0.0027147531509399414
# eprewmean -20.67
# eplenmean 839.37
# time_elapsed 1064.7330605983734
# policy_loss -0.005752102006226778
# value_loss 0.05121411383152008
# policy_entropy 1.2446303367614746
# approxkl 0.004078765865415335
# clipfrac 0.013671875
# serial_timesteps 154880
# nupdates 1210
# total_timesteps 1239040
# fps 1222
# explained_variance 0.0031426548957824707
# eprewmean -20.63
# eplenmean 852.63
# time_elapsed 1073.4846949577332
# policy_loss 0.00021972466493025422
# value_loss 0.055202025920152664
# policy_entropy 1.1056009531021118
# approxkl 0.00020253249385859817
# clipfrac 0.0
# serial_timesteps 156160
# nupdates 1220
# total_timesteps 1249280
# fps 1169
# explained_variance 0.002973794937133789
# eprewmean -20.62
# eplenmean 859.87
# time_elapsed 1082.2286841869354
# policy_loss -0.001095136278308928
# value_loss 0.05189919099211693
# policy_entropy 1.3919100761413574
# approxkl 0.0008817445486783981
# clipfrac 0.0
# serial_timesteps 157440
# nupdates 1230
# total_timesteps 1259520
# fps 1157
# explained_variance 0.0
# eprewmean -20.6
# eplenmean 865.95
# time_elapsed 1091.1297681331635
# policy_loss -0.001440392923541367
# value_loss 0.05558735132217407
# policy_entropy 1.3032735586166382
# approxkl 0.002200313378125429
# clipfrac 0.022705078125
# serial_timesteps 158720
# nupdates 1240
# total_timesteps 1269760
# fps 1148
# explained_variance 0.0
# eprewmean -20.5
# eplenmean 878.67
# time_elapsed 1100.0158421993256
# policy_loss -0.0013206461444497108
# value_loss 0.05187765881419182
# policy_entropy 1.3737703561782837
# approxkl 0.0012047950876876712
# clipfrac 0.010498046875
# serial_timesteps 160000
# nupdates 1250
# total_timesteps 1280000
# fps 1076
# explained_variance 0.002308964729309082
# eprewmean -20.49
# eplenmean 888.03
# time_elapsed 1109.1391837596893
# policy_loss -0.0024341316893696785
# value_loss 0.06322910636663437
# policy_entropy 1.3797674179077148
# approxkl 0.002250556368380785
# clipfrac 0.0
# serial_timesteps 161280
# nupdates 1260
# total_timesteps 1290240
# fps 1153
# explained_variance 0.0022994279861450195
# eprewmean -20.46
# eplenmean 890.79
# time_elapsed 1118.071899652481
# policy_loss -0.0008415600168518722
# value_loss 0.05091045796871185
# policy_entropy 1.1783961057662964
# approxkl 0.0002965707390103489
# clipfrac 0.0
# serial_timesteps 162560
# nupdates 1270
# total_timesteps 1300480
# fps 1268
# explained_variance 0.001960575580596924
# eprewmean -20.51
# eplenmean 889.23
# time_elapsed 1127.0260660648346
# policy_loss -0.002253536134958267
# value_loss 0.06985980272293091
# policy_entropy 1.0272942781448364
# approxkl 0.0016452920390293002
# clipfrac 0.02099609375
# serial_timesteps 163840
# nupdates 1280
# total_timesteps 1310720
# fps 1193
# explained_variance 0.003726065158843994
# eprewmean -20.49
# eplenmean 884.59
# time_elapsed 1135.7607941627502
# policy_loss -0.00024345677229575813
# value_loss 0.07203850150108337
# policy_entropy 1.0073041915893555
# approxkl 0.0006859705899842083
# clipfrac 0.0
# serial_timesteps 165120
# nupdates 1290
# total_timesteps 1320960
# fps 1138
# explained_variance 0.0013589859008789062
# eprewmean -20.47
# eplenmean 881.43
# time_elapsed 1144.6598088741302
# policy_loss -0.0014682887122035027
# value_loss 0.06510048359632492
# policy_entropy 1.0955204963684082
# approxkl 0.0010789589723572135
# clipfrac 0.0
# serial_timesteps 166400
# nupdates 1300
# total_timesteps 1331200
# fps 1158
# explained_variance -1.1920928955078125e-07
# eprewmean -20.43
# eplenmean 879.07
# time_elapsed 1153.7928414344788
# policy_loss -0.0018201502971351147
# value_loss 0.04576127231121063
# policy_entropy 1.2229894399642944
# approxkl 0.0014890201855450869
# clipfrac 0.0
# serial_timesteps 167680
# nupdates 1310
# total_timesteps 1341440
# fps 1254
# explained_variance 0.0
# eprewmean -20.42
# eplenmean 878.9
# time_elapsed 1162.5059802532196
# policy_loss -0.0019459675531834364
# value_loss 0.07421666383743286
# policy_entropy 1.2258538007736206
# approxkl 0.0008662051986902952
# clipfrac 0.0
# serial_timesteps 168960
# nupdates 1320
# total_timesteps 1351680
# fps 1172
# explained_variance 0.0035402774810791016
# eprewmean -20.41
# eplenmean 879.38
# time_elapsed 1171.2182195186615
# policy_loss -0.0008483832934871316
# value_loss 0.04924657940864563
# policy_entropy 1.3406031131744385
# approxkl 0.0010552905732765794
# clipfrac 0.0
# serial_timesteps 170240
# nupdates 1330
# total_timesteps 1361920
# fps 1132
# explained_variance 0.003908216953277588
# eprewmean -20.38
# eplenmean 883.67
# time_elapsed 1180.1469316482544
# policy_loss -0.0008583117742091417
# value_loss 0.05596839636564255
# policy_entropy 1.1167007684707642
# approxkl 0.00025419745361432433
# clipfrac 0.0
# serial_timesteps 171520
# nupdates 1340
# total_timesteps 1372160
# fps 1134
# explained_variance -1.1920928955078125e-07
# eprewmean -20.48
# eplenmean 863.17
# time_elapsed 1189.5020701885223
# policy_loss -0.0020981840789318085
# value_loss 0.04240094870328903
# policy_entropy 1.2717297077178955
# approxkl 0.0010290918871760368
# clipfrac 0.0
# serial_timesteps 172800
# nupdates 1350
# total_timesteps 1382400
# fps 1164
# explained_variance 0.003627002239227295
# eprewmean -20.51
# eplenmean 851.09
# time_elapsed 1198.0794970989227
# policy_loss -0.005635875277221203
# value_loss 0.054173339158296585
# policy_entropy 1.374987244606018
# approxkl 0.0038762949407100677
# clipfrac 0.036865234375
# serial_timesteps 174080
# nupdates 1360
# total_timesteps 1392640
# fps 1142
# explained_variance 0.004063010215759277
# eprewmean -20.52
# eplenmean 849.05
# time_elapsed 1207.1094615459442
# policy_loss -0.005885956808924675
# value_loss 0.047073908150196075
# policy_entropy 1.432084321975708
# approxkl 0.002373542170971632
# clipfrac 0.021240234375
# serial_timesteps 175360
# nupdates 1370
# total_timesteps 1402880
# fps 1232
# explained_variance 0.004043638706207275
# eprewmean -20.48
# eplenmean 856.29
# time_elapsed 1215.9906342029572
# policy_loss -0.0019137454219162464
# value_loss 0.06960288435220718
# policy_entropy 1.2065863609313965
# approxkl 0.001224215142428875
# clipfrac 0.0
# serial_timesteps 176640
# nupdates 1380
# total_timesteps 1413120
# fps 1190
# explained_variance 0.0
# eprewmean -20.48
# eplenmean 860.37
# time_elapsed 1224.9096283912659
# policy_loss -0.0058259498327970505
# value_loss 0.04673045873641968
# policy_entropy 0.9460965394973755
# approxkl 0.0018442005384713411
# clipfrac 0.017578125
# serial_timesteps 177920
# nupdates 1390
# total_timesteps 1423360
# fps 1162
# explained_variance 0.0012267827987670898
# eprewmean -20.47
# eplenmean 855.37
# time_elapsed 1233.9000470638275
# policy_loss -0.0026638421695679426
# value_loss 0.07254525274038315
# policy_entropy 1.0769046545028687
# approxkl 0.003288500476628542
# clipfrac 0.02099609375
# serial_timesteps 179200
# nupdates 1400
# total_timesteps 1433600
# fps 1131
# explained_variance 0.0
# eprewmean -20.51
# eplenmean 852.42
# time_elapsed 1243.1001584529877
# policy_loss 0.0008506079902872443
# value_loss 0.05780382454395294
# policy_entropy 0.9871218204498291
# approxkl 0.0009155679726973176
# clipfrac 0.0
# serial_timesteps 180480
# nupdates 1410
# total_timesteps 1443840
# fps 1106
# explained_variance 0.003981649875640869
# eprewmean -20.54
# eplenmean 847.05
# time_elapsed 1252.093932390213
# policy_loss -0.0009696433553472161
# value_loss 0.061171263456344604
# policy_entropy 1.0194666385650635
# approxkl 0.001010721200145781
# clipfrac 0.0
# serial_timesteps 181760
# nupdates 1420
# total_timesteps 1454080
# fps 1256
# explained_variance 1.7881393432617188e-07
# eprewmean -20.44
# eplenmean 859.39
# time_elapsed 1260.7744889259338
# policy_loss -0.0010516068432480097
# value_loss 0.04778425395488739
# policy_entropy 0.9914042949676514
# approxkl 0.0011594094103202224
# clipfrac 0.011474609375
# serial_timesteps 183040
# nupdates 1430
# total_timesteps 1464320
# fps 1091
# explained_variance 0.001666426658630371
# eprewmean -20.41
# eplenmean 867.85
# time_elapsed 1269.6607902050018
# policy_loss -0.0011995696695521474
# value_loss 0.0655667632818222
# policy_entropy 0.9281076788902283
# approxkl 0.0006608560215681791
# clipfrac 0.0
# serial_timesteps 184320
# nupdates 1440
# total_timesteps 1474560
# fps 1292
# explained_variance 0.0010895133018493652
# eprewmean -20.31
# eplenmean 889.0
# time_elapsed 1278.2794902324677
# policy_loss -0.000905716500710696
# value_loss 0.06954878568649292
# policy_entropy 0.9929821491241455
# approxkl 0.0025037461891770363
# clipfrac 0.0
# serial_timesteps 185600
# nupdates 1450
# total_timesteps 1484800
# fps 1131
# explained_variance 1.1682510375976562e-05
# eprewmean -20.26
# eplenmean 897.4
# time_elapsed 1286.7677400112152
# policy_loss 0.00010234274668619037
# value_loss 0.061345137655735016
# policy_entropy 1.0112693309783936
# approxkl 4.901950524072163e-05
# clipfrac 0.0
# serial_timesteps 186880
# nupdates 1460
# total_timesteps 1495040
# ...
# fps 1152
# explained_variance 0.003994941711425781
# eprewmean -21.0
# eplenmean 761.0
# time_elapsed 16978.891849279404
# policy_loss -7.275957614183426e-10
# value_loss 0.05527119338512421
# policy_entropy 3.4595632314449176e-05
# approxkl 3.5492306793213912e-15
# clipfrac 0.0
# serial_timesteps 2437120
# nupdates 19040
# total_timesteps 19496960
# fps 1117
# explained_variance 0.007974863052368164
# eprewmean -21.0
# eplenmean 760.69
# time_elapsed 16987.99958539009
# policy_loss -6.402842700481415e-10
# value_loss 0.07769472151994705
# policy_entropy 4.183830969850533e-05
# approxkl 6.683837883928855e-15
# clipfrac 0.0
# serial_timesteps 2438400
# nupdates 19050
# total_timesteps 19507200
# fps 1086
# explained_variance -0.0014944076538085938
# eprewmean -21.0
# eplenmean 760.74
# time_elapsed 16997.00152683258
# policy_loss -7.334165275096893e-09
# value_loss 0.08386072516441345
# policy_entropy 4.414200520841405e-05
# approxkl 6.621414096815055e-15
# clipfrac 0.0
# serial_timesteps 2439680
# nupdates 19060
# total_timesteps 19517440
# fps 1180
# explained_variance 0.004680812358856201
# eprewmean -21.0
# eplenmean 760.57
# time_elapsed 17005.973460912704
# policy_loss 4.0745362639427185e-10
# value_loss 0.051927126944065094
# policy_entropy 4.492985681281425e-05
# approxkl 0.0
# clipfrac 0.0
# serial_timesteps 2440960
# nupdates 19070
# total_timesteps 19527680
# fps 1097
# explained_variance 0.0040847063064575195
# eprewmean -21.0
# eplenmean 760.43
# time_elapsed 17014.885617494583
# policy_loss 6.28642737865448e-09
# value_loss 0.057745132595300674
# policy_entropy 0.0001027939870255068
# approxkl 1.1506244633301133e-14
# clipfrac 0.0
# serial_timesteps 2442240
# nupdates 19080
# total_timesteps 19537920
# fps 1119
# explained_variance 0.005296051502227783
# eprewmean -21.0
# eplenmean 760.44
# time_elapsed 17023.834637880325
# policy_loss -1.4842953532934189e-09
# value_loss 0.08479444682598114
# policy_entropy 8.048491145018488e-05
# approxkl 2.263025108018707e-13
# clipfrac 0.0
# serial_timesteps 2443520
# nupdates 19090
# total_timesteps 19548160
# fps 1112
# explained_variance 5.960464477539063e-08
# eprewmean -21.0
# eplenmean 760.39
# time_elapsed 17033.08615732193
# policy_loss -1.3795215636491776e-08
# value_loss 0.047242049127817154
# policy_entropy 9.157133172266185e-05
# approxkl 1.154617715456649e-14
# clipfrac 0.0
# serial_timesteps 2444800
# nupdates 19100
# total_timesteps 19558400
# fps 1212
# explained_variance 0.0
# eprewmean -21.0
# eplenmean 760.28
# time_elapsed 17042.134699106216
# policy_loss -5.617039278149605e-09
# value_loss 0.04346694052219391
# policy_entropy 8.823171083349735e-05
# approxkl 3.5526594686918767e-15
# clipfrac 0.0
# serial_timesteps 2446080
# nupdates 19110
# total_timesteps 19568640
# fps 1119
# explained_variance 0.006100833415985107
# eprewmean -21.0
# eplenmean 760.31
# time_elapsed 17051.115247249603
# policy_loss -6.1409082263708115e-09
# value_loss 0.06916013360023499
# policy_entropy 8.786348917055875e-05
# approxkl 6.938682145670415e-18
# clipfrac 0.0
# serial_timesteps 2447360
# nupdates 19120
# total_timesteps 19578880
# fps 1178
# explained_variance 0.0
# eprewmean -21.0
# eplenmean 760.51
# time_elapsed 17059.99322128296
# policy_loss 1.57160684466362e-09
# value_loss 0.04285899177193642
# policy_entropy 8.84357068571262e-05
# approxkl 0.0
# clipfrac 0.0
# serial_timesteps 2448640
# nupdates 19130
# total_timesteps 19589120
# fps 1302
# explained_variance 0.0
# eprewmean -21.0
# eplenmean 760.44
# time_elapsed 17068.526595830917
# policy_loss 2.0372681319713593e-10
# value_loss 0.04406952112913132
# policy_entropy 8.749152766540647e-05
# approxkl 0.0
# clipfrac 0.0
# serial_timesteps 2449920
# nupdates 19140
# total_timesteps 19599360
# fps 1184
# explained_variance 0.0049454569816589355
# eprewmean -21.0
# eplenmean 760.37
# time_elapsed 17077.459674358368
# policy_loss -5.617039278149605e-09
# value_loss 0.06455947458744049
# policy_entropy 8.802365482551977e-05
# approxkl 0.0
# clipfrac 0.0
# serial_timesteps 2451200
# nupdates 19150
# total_timesteps 19609600
# fps 1183
# explained_variance 0.0
# eprewmean -21.0
# eplenmean 760.3
# time_elapsed 17086.282381772995
# policy_loss -6.664777174592018e-09
# value_loss 0.041624318808317184
# policy_entropy 8.682680345373228e-05
# approxkl 2.220429108591368e-15
# clipfrac 0.0
# serial_timesteps 2452480
# nupdates 19160
# total_timesteps 19619840
# fps 1137
# explained_variance 0.003479182720184326
# eprewmean -21.0
# eplenmean 760.41
# time_elapsed 17094.927907705307
# policy_loss 6.402842700481415e-10
# value_loss 0.05579156428575516
# policy_entropy 8.410347800236195e-05
# approxkl 2.6558209841390235e-15
# clipfrac 0.0
# serial_timesteps 2453760
# nupdates 19170
# total_timesteps 19630080
# fps 1014
# explained_variance 0.0036947131156921387
# eprewmean -21.0
# eplenmean 760.39
# time_elapsed 17103.81196665764
# policy_loss 3.812601789832115e-09
# value_loss 0.08923250436782837
# policy_entropy 8.87532951310277e-05
# approxkl 1.6320027740237414e-14
# clipfrac 0.0
# serial_timesteps 2455040
# nupdates 19180
# total_timesteps 19640320
# fps 1107
# explained_variance 0.0
# eprewmean -21.0
# eplenmean 760.34
# time_elapsed 17112.672255277634
# policy_loss -1.3969838619232178e-09
# value_loss 0.043710630387067795
# policy_entropy 9.392538777319714e-05
# approxkl 1.64311211934675e-14
# clipfrac 0.0
# serial_timesteps 2456320
# nupdates 19190
# total_timesteps 19650560
# fps 1174
# explained_variance 0.00421518087387085
# eprewmean -21.0
# eplenmean 760.25
# time_elapsed 17121.81263780594
# policy_loss -6.402842700481415e-10
# value_loss 0.05573858693242073
# policy_entropy 8.891762990970165e-05
# approxkl 0.0
# clipfrac 0.0
# serial_timesteps 2457600
# nupdates 19200
# total_timesteps 19660800
# fps 1159
# explained_variance 0.007801651954650879
# eprewmean -21.0
# eplenmean 760.45
# time_elapsed 17130.843681573868
# policy_loss -3.4633558243513107e-09
# value_loss 0.07185821980237961
# policy_entropy 8.774136222200468e-05
# approxkl 0.0
# clipfrac 0.0
# serial_timesteps 2458880
# nupdates 19210
# total_timesteps 19671040
# fps 1142
# explained_variance 0.002172529697418213
# eprewmean -21.0
# eplenmean 760.56
# time_elapsed 17139.861409902573
# policy_loss 3.841705620288849e-09
# value_loss 0.07111833989620209
# policy_entropy 8.726113446755335e-05
# approxkl 6.938682145670415e-18
# clipfrac 0.0
# serial_timesteps 2460160
# nupdates 19220
# total_timesteps 19681280
# fps 1175
# explained_variance 0.004685640335083008
# eprewmean -21.0
# eplenmean 760.66
# time_elapsed 17148.589044570923
# policy_loss 4.307366907596588e-09
# value_loss 0.05218454822897911
# policy_entropy 8.688564412295818e-05
# approxkl 3.4693940123944108e-18
# clipfrac 0.0
# serial_timesteps 2461440
# nupdates 19230
# total_timesteps 19691520
# fps 1107
# explained_variance 0.007923722267150879
# eprewmean -21.0
# eplenmean 760.87
# time_elapsed 17157.621374368668
# policy_loss 6.111804395914078e-10
# value_loss 0.05835016816854477
# policy_entropy 8.614199759904295e-05
# approxkl 0.0
# clipfrac 0.0
# serial_timesteps 2462720
# nupdates 19240
# total_timesteps 19701760
# fps 1032
# explained_variance 0.0052269697189331055
# eprewmean -21.0
# eplenmean 760.74
# time_elapsed 17167.199917554855
# policy_loss 2.9103830456733704e-10
# value_loss 0.08639297634363174
# policy_entropy 9.90309490589425e-05
# approxkl 2.2752730689107326e-12
# clipfrac 0.0
# serial_timesteps 2464000
# nupdates 19250
# total_timesteps 19712000
# fps 1296
# explained_variance -1.1920928955078125e-07
# eprewmean -21.0
# eplenmean 760.7
# time_elapsed 17176.397415161133
# policy_loss -3.6088749766349792e-09
# value_loss 0.04197908937931061
# policy_entropy 9.018743730848655e-05
# approxkl 0.0
# clipfrac 0.0
# serial_timesteps 
# approxkl 4.440858217182736e-16
# clipfrac 0.0
# serial_timesteps 2490880
# nupdates 19460
# total_timesteps 19927040
# fps 1115
# explained_variance 0.0035193562507629395
# eprewmean -21.0
# eplenmean 760.29
# time_elapsed 17361.92266893387
# policy_loss -1.5570549294352531e-09
# value_loss 0.0763866975903511
# policy_entropy 5.2820007113041356e-05
# approxkl 3.5301351685584903e-15
# clipfrac 0.0
# serial_timesteps 2492160
# nupdates 19470
# total_timesteps 19937280
# fps 1187
# explained_variance 0.0
# eprewmean -21.0
# eplenmean 760.37
# time_elapsed 17370.80867433548
# policy_loss 3.3760443329811096e-09
# value_loss 0.04018333926796913
# policy_entropy 5.086959936306812e-05
# approxkl 0.0
# clipfrac 0.0
# serial_timesteps 2493440
# nupdates 19480
# total_timesteps 19947520
# fps 1155
# explained_variance 0.0024833083152770996
# eprewmean -21.0
# eplenmean 760.29
# time_elapsed 17379.827117919922
# policy_loss 8.440110832452774e-10
# value_loss 0.05617128312587738
# policy_entropy 5.137791595188901e-05
# approxkl 0.0
# clipfrac 0.0
# serial_timesteps 2494720
# nupdates 19490
# total_timesteps 19957760
# fps 1052
# explained_variance 0.0062372684478759766
# eprewmean -21.0
# eplenmean 760.31
# time_elapsed 17389.044401407242
# policy_loss -1.3096723705530167e-09
# value_loss 0.08150780200958252
# policy_entropy 5.222158142714761e-05
# approxkl 0.0
# clipfrac 0.0
# serial_timesteps 2496000
# nupdates 19500
# total_timesteps 19968000
# fps 1197
# explained_variance -0.0004203319549560547
# eprewmean -21.0
# eplenmean 760.3
# time_elapsed 17398.01438641548
# policy_loss 9.74978320300579e-10
# value_loss 0.05906324461102486
# policy_entropy 5.1707684178836644e-05
# approxkl 3.4693940123944108e-18
# clipfrac 0.0
# serial_timesteps 2497280
# nupdates 19510
# total_timesteps 19978240
# fps 1144
# explained_variance 0.004321932792663574
# eprewmean -21.0
# eplenmean 760.28
# time_elapsed 17407.00327038765
# policy_loss 1.3387762010097504e-09
# value_loss 0.05859547480940819
# policy_entropy 5.169855649000965e-05
# approxkl 0.0
# clipfrac 0.0
# serial_timesteps 2498560
# nupdates 19520
# total_timesteps 19988480
# fps 1115
# explained_variance 0.0075220465660095215
# eprewmean -21.0
# eplenmean 760.42
# time_elapsed 17416.006729841232
# policy_loss -8.731149137020111e-11
# value_loss 0.07039093971252441
# policy_entropy 5.2061510359635577e-05
# approxkl 0.0
# clipfrac 0.0
# serial_timesteps 2499840
# nupdates 19530
# total_timesteps 19998720
# fps 1130
# explained_variance 0.0006347298622131348
# eprewmean -21.0
# eplenmean 760.43
# time_elapsed 17425.02486371994
# policy_loss -1.2223608791828156e-09
# value_loss 0.08350394666194916
# policy_entropy 5.207775393500924e-05
# approxkl 2.9490074098479106e-17
# clipfrac 0.0

# %%
# After learning ends, save trained agent
model.save(save_path +'/model')

# %% [markdown]
# #### To see your trained agent in action, go to the Jupyter file browser and download the saved model in the pong-ppo folder. Then, run the command below from your local machine (with the env_id set above and the model file's local path passed in as arguments):

# %%
"""
python -m baselines.run --alg=ppo2 --env=ENV_ID --num_timesteps=0 --load_path=LOCAL_MODEL_PATH --play
"""
# Out:
# '\npython -m baselines.run --alg=ppo2 --env=ENV_ID --num_timesteps=0 --load_path=LOCAL_MODEL_PATH --play\n'
